# %% [markdown]
# # CoinGecko

# %%
# !poetry add pycoingecko
# Out:
# Using version ^1.4.0 for pycoingecko
#
# Updating dependencies
# Resolving dependencies... (0.7s)
#
# Writing lock file
#
# Package operations: 1 install, 0 updates, 0 removals
#
#   • Installing pycoingecko (1.4.0): Pending...
#   • Installing pycoingecko (1.4.0): Downloading... 0%
#   • Installing pycoingecko (1.4.0): Downloading... 100%
#   • Installing pycoingecko (1.4.0): Downloading... 100%
#   • Installing pycoingecko (1.4.0): Installing...
#   • Installing pycoingecko (1.4.0)

# %%
from pycoingecko import CoinGeckoAPI
cg = CoinGeckoAPI()

# %%
cg.get_price(ids='polkastarter', vs_currencies='usd')
# Out:
# {'polkastarter': {'usd': 2.43}}

# %%
cg.get_coins_list()
# Out:
# [{'id': '01coin', 'symbol': 'zoc', 'name': '01coin'},
#  {'id': '0-5x-long-algorand-token',
#   'symbol': 'algohalf',
#   'name': '0.5X Long Algorand Token'},
#  {'id': '0-5x-long-altcoin-index-token',
#   'symbol': 'althalf',
#   'name': '0.5X Long Altcoin Index Token'},
#  {'id': '0-5x-long-balancer-token',
#   'symbol': 'balhalf',
#   'name': '0.5X Long Balancer Token'},
#  {'id': '0-5x-long-bitcoin-cash-token',
#   'symbol': 'bchhalf',
#   'name': '0.5X Long Bitcoin Cash Token'},
#  {'id': '0-5x-long-bitcoin-sv-token',
#   'symbol': 'bsvhalf',
#   'name': '0.5X Long Bitcoin SV Token'},
#  {'id': '0-5x-long-bitcoin-token',
#   'symbol': 'half',
#   'name': '0.5X Long Bitcoin Token'},
#  {'id': '0-5x-long-bnb-token',
#   'symbol': 'bnbhalf',
#   'name': '0.5X Long BNB Token'},
#  {'id': '0-5x-long-cardano-token',
#   'symbol': 'adahalf',
#   'name': '0.5X Long Cardano Token'},
#  {'id': '0-5x-long-chainlink-token',
#   'symbol': 'linkhalf',
# ...

# %%
x = cg.get_coin_market_chart_by_id(id='blurt', 
                                 vs_currency ='btc', days = 120)

# %%
x.keys()
# Out:
# dict_keys(['prices', 'market_caps', 'total_volumes'])

# %%
cg.get_coins_markets(vs_currency='gbp')
# Out:
# [{'id': 'bitcoin',
#   'symbol': 'btc',
#   'name': 'Bitcoin',
#   'image': 'https://assets.coingecko.com/coins/images/1/large/bitcoin.png?1547033579',
#   'current_price': 33963,
#   'market_cap': 635475260607,
#   'market_cap_rank': 1,
#   'fully_diluted_valuation': 716541027376,
#   'total_volume': 62828634234,
#   'high_24h': 34868,
#   'low_24h': 30991,
#   'price_change_24h': 1836.34,
#   'price_change_percentage_24h': 5.71591,
#   'market_cap_change_24h': 40022243277,
#   'market_cap_change_percentage_24h': 6.72131,
#   'circulating_supply': 18624168.0,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 34868,
#   'ath_change_percentage': -2.54749,
#   'ath_date': '2021-02-09T07:02:15.097Z',
#   'atl': 43.9,
#   'atl_change_percentage': 77298.53435,
#   'atl_date': '2013-07-05T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-02-09T16:12:47.939Z'},
#  {'id': 'ethereum',
#   'symbol': 'eth',
#   'name': 'Ethereum',
# ...

# %%
cg.get_coin_history_by_id(id='bitcoin', date='01-02-2021')
# Out:
# {'id': 'bitcoin',
#  'symbol': 'btc',
#  'name': 'Bitcoin',
#  'localization': {'en': 'Bitcoin',
#   'de': 'Bitcoin',
#   'es': 'Bitcoin',
#   'fr': 'Bitcoin',
#   'it': 'Bitcoin',
#   'pl': 'Bitcoin',
#   'ro': 'Bitcoin',
#   'hu': 'Bitcoin',
#   'nl': 'Bitcoin',
#   'pt': 'Bitcoin',
#   'sv': 'Bitcoin',
#   'vi': 'Bitcoin',
#   'tr': 'Bitcoin',
#   'ru': 'биткоин',
#   'ja': 'ビットコイン',
#   'zh': '比特币',
#   'zh-tw': '比特幣',
#   'ko': '비트코인',
#   'ar': 'بيتكوين',
#   'th': 'บิตคอยน์',
#   'id': 'Bitcoin'},
#  'image': {'thumb': 'https://assets.coingecko.com/coins/images/1/thumb/bitcoin.png?1547033579',
#   'small': 'https://assets.coingecko.com/coins/images/1/small/bitcoin.png?1547033579'},
#  'market_data': {'current_price': {'aed': 121450.89650487158,
#    'ars': 2882084.037674111,
#    'aud': 43382.62041287536,
#    'bch': 82.77407667701861,
#    'bdt': 2797999.028463702,
#    'bhd': 12465.622999885325,
#    'bmd': 33064.78676701507,
#    'bnb': 749.2512625523594,
# ...

# %%
cg.get_exchanges_list()
# Out:
# [{'id': 'binance',
#   'name': 'Binance',
#   'year_established': 2017,
#   'country': 'Cayman Islands',
#   'description': '',
#   'url': 'https://www.binance.com/',
#   'image': 'https://assets.coingecko.com/markets/images/52/small/binance.jpg?1519353250',
#   'has_trading_incentive': False,
#   'trust_score': 10,
#   'trust_score_rank': 1,
#   'trade_volume_24h_btc': 676524.9482504979,
#   'trade_volume_24h_btc_normalized': 676524.9482504979},
#  {'id': 'gdax',
#   'name': 'Coinbase Pro',
#   'year_established': 2012,
#   'country': 'United States',
#   'description': '',
#   'url': 'https://www.coinbase.com',
#   'image': 'https://assets.coingecko.com/markets/images/23/small/fe290a14-ac8f-4c90-9aed-5e72abf271f0.jpeg?1527171545',
#   'has_trading_incentive': False,
#   'trust_score': 10,
#   'trust_score_rank': 2,
#   'trade_volume_24h_btc': 107076.97692205847,
#   'trade_volume_24h_btc_normalized': 107076.97692205847},
#  {'id': 'kraken',
#   'name': 'Kraken',
# ...

# %%
cg.get_search_trending()
# Out:
# {'coins': [{'item': {'id': 'decentr',
#     'name': 'Decentr',
#     'symbol': 'DEC',
#     'market_cap_rank': 376,
#     'thumb': 'https://assets.coingecko.com/coins/images/11816/thumb/Decentr.png?1594637985',
#     'large': 'https://assets.coingecko.com/coins/images/11816/large/Decentr.png?1594637985',
#     'score': 0}},
#   {'item': {'id': 'pancakeswap-token',
#     'name': 'PancakeSwap',
#     'symbol': 'CAKE',
#     'market_cap_rank': 76,
#     'thumb': 'https://assets.coingecko.com/coins/images/12632/thumb/IMG_0440.PNG?1602654093',
#     'large': 'https://assets.coingecko.com/coins/images/12632/large/IMG_0440.PNG?1602654093',
#     'score': 1}},
#   {'item': {'id': 'tornado-cash',
#     'name': 'Tornado Cash',
#     'symbol': 'TORN',
#     'market_cap_rank': 327,
#     'thumb': 'https://assets.coingecko.com/coins/images/13496/thumb/ZINt8NSB_400x400.jpg?1609193407',
#     'large': 'https://assets.coingecko.com/coins/images/13496/large/ZINt8NSB_400x400.jpg?1609193407',
# ...

# %%
cg.get_global_decentralized_finance_defi()
# Out:
# {'defi_market_cap': '69829992724.833491122427862744',
#  'eth_market_cap': '197885700640.0981645741761735865',
#  'defi_to_eth_ratio': '35.288043804557565511466264581761403064156724937340767784959271',
#  'trading_volume_24h': '14755310442.42334908001910840439',
#  'defi_dominance': '5.0371128001014136710938851219909817238694435560143403',
#  'top_coin_name': 'Chainlink',
#  'top_coin_defi_dominance': 14.567833489500787}
