# %%
import os
from dotenv import dotenv_values
import ccxt

# %%
config = dotenv_values("../../.env") 
config
# Out:
# {'CB_PRO_API_KEY': '59103061a751956ccdc3acd63c4c8381',
#  'CB_PRO_SECRET': 'lC1SCOFfOTfwotem3MSWk7QmhpxaV68qGZK8YIZfsoDlulxktMxNAGSlEMVzpA22vl1WDdFzEEe9f3P/8CJAtg==',
#  'CB_PRO_PASSWORD': '006uf3i5hbvx',
#  'GN_API_KEY': '1uLeEOfOFGJUcQH6ZvHvo6WoBdT'}

# %%
exchange_id = 'coinbasepro'
exchange_class = getattr(ccxt, exchange_id)
cb_pro = exchange_class({
    'apiKey': config['CB_PRO_API_KEY'],
    'secret': config['CB_PRO_SECRET'],
    'password': config['CB_PRO_PASSWORD'],
    'timeout': 30000,
    'enableRateLimit': True,
})

# %%
config['CB_PRO_API_KEY']
# Out:
# '59103061a751956ccdc3acd63c4c8381'

# %%
dir(cb_pro)
# Out:
# ['__class__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'account',
#  'accounts',
#  'aggregate',
#  'aiohttpProxy',
#  'aiohttpTrustEnv',
#  'aiohttp_proxy',
#  'aiohttp_trust_env',
#  'amountToPrecision',
#  'amount_to_precision',
#  'api',
#  'apiKey',
#  'arrayConcat',
#  'array_concat',
#  'asyncioLoop',
#  'asyncio_loop',
#  'balance',
#  'base16ToBinary',
#  'base16_to_binary',
#  'base58Alphabet',
#  'base58Decoder',
#  'base58Encoder',
#  'base58ToBinary',
#  'base58_alphabet',
#  'base58_decoder',
#  'base58_encoder',
#  'base58_to_binary',
#  'base64ToBinary',
#  'base64ToString',
# ...

# %%
cb_pro.fetch_balance()
# Out:
# {'info': [{'id': '0728e94f-7c58-4ac1-a97a-758900417b85',
#    'currency': '1INCH',
#    'balance': '0.0000000000000000',
#    'hold': '0.0000000000000000',
#    'available': '0',
#    'profile_id': '8588e7cb-ccff-44da-b4b8-c47c7900b600',
#    'trading_enabled': True},
#   {'id': 'acdb0b97-a4c4-4028-8899-8e7886086599',
#    'currency': 'AAVE',
#    'balance': '0.0000000000000000',
#    'hold': '0.0000000000000000',
#    'available': '0',
#    'profile_id': '8588e7cb-ccff-44da-b4b8-c47c7900b600',
#    'trading_enabled': True},
#   {'id': 'b04f39af-5579-4bfd-8435-1b3c3ed75ce2',
#    'currency': 'ADA',
#    'balance': '0.0000000000000000',
#    'hold': '0.0000000000000000',
#    'available': '0',
#    'profile_id': '8588e7cb-ccff-44da-b4b8-c47c7900b600',
#    'trading_enabled': True},
#   {'id': '147b4bc5-99e8-4a67-ab82-042381903f9b',
#    'currency': 'ALGO',
#    'balance': '0.0000000000000000',
#    'hold': '0.0000000000000000',
#    'available': '0',
# ...

# %%
symbols = cb_pro.symbols
symbols
# Out:
# ['1INCH/BTC',
#  '1INCH/EUR',
#  '1INCH/GBP',
#  '1INCH/USD',
#  'AAVE/BTC',
#  'AAVE/EUR',
#  'AAVE/GBP',
#  'AAVE/USD',
#  'ADA/BTC',
#  'ADA/ETH',
#  'ADA/EUR',
#  'ADA/GBP',
#  'ADA/USD',
#  'ADA/USDC',
#  'ALGO/BTC',
#  'ALGO/EUR',
#  'ALGO/GBP',
#  'ALGO/USD',
#  'AMP/USD',
#  'ANKR/BTC',
#  'ANKR/EUR',
#  'ANKR/GBP',
#  'ANKR/USD',
#  'ATOM/BTC',
#  'ATOM/USD',
#  'BAL/BTC',
#  'BAL/USD',
#  'BAND/BTC',
#  'BAND/EUR',
#  'BAND/GBP',
#  'BAND/USD',
#  'BAT/BTC',
#  'BAT/ETH',
#  'BAT/EUR',
#  'BAT/USD',
#  'BAT/USDC',
#  'BCH/BTC',
#  'BCH/EUR',
#  'BCH/GBP',
#  'BCH/USD',
#  'BNT/BTC',
#  'BNT/EUR',
#  'BNT/GBP',
#  'BNT/USD',
#  'BTC/EUR',
#  'BTC/GBP',
#  'BTC/USD',
#  'BTC/USDC',
#  'BTC/USDT',
#  'CELO/BTC',
#  'CELO/EUR',
#  'CELO/GBP',
#  'CELO/USD',
#  'CHZ/EUR',
#  'CHZ/GBP',
#  'CHZ/USD',
#  'CHZ/USDT',
#  'COMP/BTC',
#  'COMP/USD',
#  'CRV/BTC',
#  'CRV/EUR',
#  'CRV/GBP',
#  'CRV/USD',
#  'CTSI/BTC',
#  'CTSI/USD',
#  'CVC/USDC',
#  'DAI/USD',
#  'DAI/USDC',
# ...

# %%
markets = cb_pro.load_markets()
markets
# Out:
# {'LRC/USD': {'percentage': True,
#   'tierBased': True,
#   'maker': 0.005,
#   'taker': 0.005,
#   'precision': {'amount': 1e-06, 'price': 0.0001},
#   'limits': {'amount': {'min': 1.0, 'max': 560000.0},
#    'price': {'min': 0.0001, 'max': None},
#    'cost': {'min': 1.0, 'max': 100000.0}},
#   'id': 'LRC-USD',
#   'symbol': 'LRC/USD',
#   'baseId': 'LRC',
#   'quoteId': 'USD',
#   'base': 'LRC',
#   'quote': 'USD',
#   'active': True,
#   'info': {'id': 'LRC-USD',
#    'base_currency': 'LRC',
#    'quote_currency': 'USD',
#    'base_min_size': '1',
#    'base_max_size': '560000',
#    'quote_increment': '0.0001',
#    'base_increment': '0.000001',
#    'display_name': 'LRC/USD',
#    'min_market_funds': '1.0',
#    'max_market_funds': '100000',
#    'margin_enabled': False,
#    'post_only': False,
#    'limit_only': False,
#    'cancel_only': False,
#    'trading_disabled': False,
#    'status': 'online',
#    'status_message': ''}},
#  'BAND/GBP': {'percentage': True,
# ...

# %%
cb_pro.fetchMyTrades('ETH/GBP')
# Out:
# [{'id': '2558787',
#   'order': '7feccf91-17ad-407e-9840-9350592f6bf4',
#   'info': {'created_at': '2021-01-09T16:10:43.794Z',
#    'trade_id': '2558787',
#    'product_id': 'ETH-GBP',
#    'order_id': '7feccf91-17ad-407e-9840-9350592f6bf4',
#    'user_id': '5c346591f83e2a0c0c9b7816',
#    'profile_id': '8588e7cb-ccff-44da-b4b8-c47c7900b600',
#    'liquidity': 'T',
#    'price': '901.35000000',
#    'size': '0.01787890',
#    'fee': '0.0805757325750000',
#    'side': 'buy',
#    'settled': True,
#    'usd_volume': '21.8460491210000000'},
#   'timestamp': 1610208643794,
#   'datetime': '2021-01-09T16:10:43.794Z',
#   'symbol': 'ETH/GBP',
#   'type': None,
#   'takerOrMaker': 'taker',
#   'side': 'buy',
#   'price': 901.35,
#   'amount': 0.0178789,
#   'fee': {'cost': 0.080575732575, 'currency': 'GBP', 'rate': 0.005},
#   'cost': 16.115146515},
#  {'id': '2558786',
#   'order': '7feccf91-17ad-407e-9840-9350592f6bf4',
#   'info': {'created_at': '2021-01-09T16:10:43.794Z',
# ...

# %%
ticker = cb_pro.fetch_ticker('DOT/USDT')
ticker
# Out:
# {'symbol': 'DOT/USDT',
#  'timestamp': 1624220055123,
#  'datetime': '2021-06-20T20:14:15.123Z',
#  'high': None,
#  'low': None,
#  'bid': 20.825,
#  'bidVolume': None,
#  'ask': 20.882,
#  'askVolume': None,
#  'vwap': None,
#  'open': None,
#  'close': 20.815,
#  'last': 20.815,
#  'previousClose': None,
#  'change': None,
#  'percentage': None,
#  'average': None,
#  'baseVolume': 13815.15,
#  'quoteVolume': None,
#  'info': {'trade_id': '4142',
#   'price': '20.815',
#   'size': '0.001',
#   'time': '2021-06-20T20:14:15.123391Z',
#   'bid': '20.825',
#   'ask': '20.882',
#   'volume': '13815.15'}}
